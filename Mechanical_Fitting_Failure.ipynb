# %% [markdown]
# <a href="https://colab.research.google.com/github/YesithW/Predictive_Maintenance/blob/main/Mechanical_Fitting_Failure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.11/dist-packages (0.3.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (2025.7.14)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("binovi/mechanical-fitting-failure-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/mechanical-fitting-failure-data

# %%
import pandas as pd
import os

# Find your CSV file
for file in os.listdir(path):
    if file.endswith(".csv"):
        data_path = os.path.join(path, file)

# Load it
df = pd.read_csv(data_path)
df.head()
# Out:
#   DATAFILE_AS_OF          FORM_REV  OPERATOR_ID  REPORT_YEAR  \
# 0       4/3/2018  7100.1-2 10-2014         1209         2018
# 1       4/3/2018  7100.1-2 10-2014         1209         2018
# 2       4/3/2018  7100.1-2 10-2014         1209         2018
# 3       4/3/2018  7100.1-2 10-2014         1209         2018
# 4       4/3/2018  7100.1-2 10-2014         1209         2018
#
#        REPORT_NUMBER  SUPPLEMENTAL_NUMBER REPORT_TYPE REPORT_DATE FILING_DATE  \
# 0  20180227120985471                85414     INITIAL    3/6/2018    3/6/2018
# 1  20180219120985470                85413     INITIAL    3/6/2018    3/6/2018
# 2  20180216120985468                85411     INITIAL    3/6/2018    3/6/2018
# 3  20180215120985467                85410     INITIAL    3/6/2018    3/6/2018
# 4  20180215120985466                85409     INITIAL    3/6/2018    3/6/2018
#
#                    OPERATOR_NAME  ... SECOND_PIPE_MATERIAL_OTHER  \
# 0  COLUMBIA GAS OF MASSACHUSETTS  ...                        NaN
# 1  COLUMBIA GAS OF MASSACHUSETTS  ...                        NaN
# 2  COLUMBIA GAS OF MASSACHUSETTS  ...                        NaN
# 3  COLUMBIA GAS OF MASSACHUSETTS  ...                        NaN
# 4  COLUMBIA GAS OF MASSACHUSETTS  ...                        NaN
#
#   SECOND_PIPE_PLASTIC_TEXT SECOND_PIPE_PLASTIC_OTHER LEAK_CAUSE_TEXT  \
# 0                      NaN                       NaN           OTHER
# 1        POLYETHYLENE (PE)                       NaN       CORROSION
# 2                      NaN                       NaN           OTHER
# 3                      NaN                       NaN           OTHER
# 4                      NaN                       NaN  NATURAL FORCES
#
#   LEAK_CAUSE_OTHER NF_THERMAL_EXP_TEXT EX_DAMAGE_OCCURRED_TEXT  \
# 0   NOT DETERMINED                 NaN                     NaN
# 1              NaN                 NaN                     NaN
# 2   NOT DETERMINED                 NaN                     NaN
# 3   NOT DETERMINED                 NaN                     NaN
# 4              NaN                  NO                     NaN
#
#   MAT_WELDS_LEAK_CAUSE_TEXT   LEAK_OCCURRED_TEXT MFF_NUMBER_FROM_OPERATOR
# 0                       NaN  LEAKED THROUGH SEAL                 00028186
# 1                       NaN  LEAKED THROUGH BODY                 00028008
# 2                       NaN  LEAKED THROUGH SEAL                 00027950
# 3                       NaN  LEAKED THROUGH SEAL                 00027949
# 4                       NaN  LEAKED THROUGH SEAL                 00027912
#
# [5 rows x 54 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85611 entries, 0 to 85610
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DATAFILE_AS_OF                 85611 non-null  object
#  1   FORM_REV                       85611 non-null  object
#  2   OPERATOR_ID                    85611 non-null  int64
#  3   REPORT_YEAR                    85611 non-null  int64
#  4   REPORT_NUMBER                  85611 non-null  int64
#  5   SUPPLEMENTAL_NUMBER            85611 non-null  int64
#  6   REPORT_TYPE                    85611 non-null  object
#  7   REPORT_DATE                    85611 non-null  object
#  8   FILING_DATE                    85611 non-null  object
#  9   OPERATOR_NAME                  85611 non-null  object
#  10  HQ_ADDRESS_STREET              85611 non-null  object
#  11  HQ_ADDRESS_CITY                85611 non-null  object
#  12  HQ_ADDRESS_COUNTY              6266 non-null   object
#  13  HQ_ADDRESS_STATE               85611 non-null  object
#  14  HQ_ADDRESS_ZIP                 85611 non-null  object
#  15  FAILURE_STATE                  85611 non-null  object
#  16  FAILURE_DATE                   85611 non-null  object
#  17  MF_INVOLVED_TEXT               85611 non-null  object
#  18  MF_INVOLVED_OTHER              14177 non-null  object
#  19  MF_TYPE_TEXT                   85611 non-null  object
#  20  MF_TYPE_OTHER                  3054 non-null   object
#  21  LEAK_LOCATION_A_TEXT           85602 non-null  object
#  22  LEAK_LOCATION_B_TEXT           85611 non-null  object
#  23  LEAK_LOCATION_C_TEXT           85611 non-null  object
#  24  YEAR_INSTALLED                 62279 non-null  object
#  25  YEAR_MANUFACTURED              58424 non-null  object
#  26  DECADE_INSTALLED               8364 non-null   object
#  27  MANUFACTURE                    85558 non-null  object
#  28  MANUFACTURE_MAPPED             85611 non-null  object
#  29  MANUFACTURE_OTHER              2928 non-null   object
#  30  MODEL_NUMBER                   85017 non-null  object
#  31  LOT_NUMBER                     84639 non-null  object
#  32  LOT_ATTRIBUTES                 10594 non-null  object
#  33  FITTING_MATERIAL_TEXT          85611 non-null  object
#  34  FITTING_MATERIAL_OTHER         1200 non-null   object
#  35  FIRST_PIPE_NOMINAL_SIZE_TEXT   85611 non-null  object
#  36  FIRST_PIPE_UNIT_TEXT           85611 non-null  object
#  37  FIRST_PIPE_MATERIAL_TEXT       85611 non-null  object
#  38  FIRST_PIPE_MATERIAL_OTHER      2766 non-null   object
#  39  FIRST_PIPE_PLASTIC_TEXT        26758 non-null  object
#  40  FIRST_PIPE_PLASTIC_OTHER       54 non-null     object
#  41  SECOND_PIPE_NOMINAL_SIZE_TEXT  85314 non-null  object
#  42  SECOND_PIPE_UNIT_TEXT          85316 non-null  object
#  43  SECOND_PIPE_MATERIAL_TEXT      85316 non-null  object
#  44  SECOND_PIPE_MATERIAL_OTHER     337 non-null    object
#  45  SECOND_PIPE_PLASTIC_TEXT       27029 non-null  object
#  46  SECOND_PIPE_PLASTIC_OTHER      43 non-null     object
#  47  LEAK_CAUSE_TEXT                85611 non-null  object
#  48  LEAK_CAUSE_OTHER               6344 non-null   object
#  49  NF_THERMAL_EXP_TEXT            12845 non-null  object
#  50  EX_DAMAGE_OCCURRED_TEXT        2108 non-null   object
#  51  MAT_WELDS_LEAK_CAUSE_TEXT      12551 non-null  object
#  52  LEAK_OCCURRED_TEXT             85611 non-null  object
#  53  MFF_NUMBER_FROM_OPERATOR       74232 non-null  object
# dtypes: int64(4), object(50)
# memory usage: 35.3+ MB

# %%
# Show value counts for the column
repeated_values = df['NF_THERMAL_EXP_TEXT'].value_counts()

# Filter only repeated ones
repeated_values = repeated_values[repeated_values > 1]

print("Repeated values:")
print(repeated_values)
# Out:
# Repeated values:
# NF_THERMAL_EXP_TEXT
# YES    6424
# NO     6421
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85611 entries, 0 to 85610
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DATAFILE_AS_OF                 85611 non-null  object
#  1   FORM_REV                       85611 non-null  object
#  2   OPERATOR_ID                    85611 non-null  int64
#  3   REPORT_YEAR                    85611 non-null  int64
#  4   REPORT_NUMBER                  85611 non-null  int64
#  5   SUPPLEMENTAL_NUMBER            85611 non-null  int64
#  6   REPORT_TYPE                    85611 non-null  object
#  7   REPORT_DATE                    85611 non-null  object
#  8   FILING_DATE                    85611 non-null  object
#  9   OPERATOR_NAME                  85611 non-null  object
#  10  HQ_ADDRESS_STREET              85611 non-null  object
#  11  HQ_ADDRESS_CITY                85611 non-null  object
#  12  HQ_ADDRESS_COUNTY              6266 non-null   object
#  13  HQ_ADDRESS_STATE               85611 non-null  object
#  14  HQ_ADDRESS_ZIP                 85611 non-null  object
#  15  FAILURE_STATE                  85611 non-null  object
#  16  FAILURE_DATE                   85611 non-null  object
#  17  MF_INVOLVED_TEXT               85611 non-null  object
#  18  MF_INVOLVED_OTHER              14177 non-null  object
#  19  MF_TYPE_TEXT                   85611 non-null  object
#  20  MF_TYPE_OTHER                  3054 non-null   object
#  21  LEAK_LOCATION_A_TEXT           85602 non-null  object
#  22  LEAK_LOCATION_B_TEXT           85611 non-null  object
#  23  LEAK_LOCATION_C_TEXT           85611 non-null  object
#  24  YEAR_INSTALLED                 62279 non-null  object
#  25  YEAR_MANUFACTURED              58424 non-null  object
#  26  DECADE_INSTALLED               8364 non-null   object
#  27  MANUFACTURE                    85558 non-null  object
#  28  MANUFACTURE_MAPPED             85611 non-null  object
#  29  MANUFACTURE_OTHER              2928 non-null   object
#  30  MODEL_NUMBER                   85017 non-null  object
#  31  LOT_NUMBER                     84639 non-null  object
#  32  LOT_ATTRIBUTES                 10594 non-null  object
#  33  FITTING_MATERIAL_TEXT          85611 non-null  object
#  34  FITTING_MATERIAL_OTHER         1200 non-null   object
#  35  FIRST_PIPE_NOMINAL_SIZE_TEXT   85611 non-null  object
#  36  FIRST_PIPE_UNIT_TEXT           85611 non-null  object
#  37  FIRST_PIPE_MATERIAL_TEXT       85611 non-null  object
#  38  FIRST_PIPE_MATERIAL_OTHER      2766 non-null   object
#  39  FIRST_PIPE_PLASTIC_TEXT        26758 non-null  object
#  40  FIRST_PIPE_PLASTIC_OTHER       54 non-null     object
#  41  SECOND_PIPE_NOMINAL_SIZE_TEXT  85314 non-null  object
#  42  SECOND_PIPE_UNIT_TEXT          85316 non-null  object
#  43  SECOND_PIPE_MATERIAL_TEXT      85316 non-null  object
#  44  SECOND_PIPE_MATERIAL_OTHER     337 non-null    object
#  45  SECOND_PIPE_PLASTIC_TEXT       27029 non-null  object
#  46  SECOND_PIPE_PLASTIC_OTHER      43 non-null     object
#  47  LEAK_CAUSE_TEXT                85611 non-null  object
#  48  LEAK_CAUSE_OTHER               6344 non-null   object
#  49  NF_THERMAL_EXP_TEXT            12845 non-null  object
#  50  EX_DAMAGE_OCCURRED_TEXT        2108 non-null   object
#  51  MAT_WELDS_LEAK_CAUSE_TEXT      12551 non-null  object
#  52  LEAK_OCCURRED_TEXT             85611 non-null  object
#  53  MFF_NUMBER_FROM_OPERATOR       74232 non-null  object
# dtypes: int64(4), object(50)
# memory usage: 35.3+ MB

# %%
# Remove columns by name
columns_to_drop = ['MF_INVOLVED_OTHER', 'MF_TYPE_OTHER', 'DECADE_INSTALLED', 'MANUFACTURE_OTHER', 'MANUFACTURE_MAPPED', 'LOT_NUMBER', 'LOT_ATTRIBUTES','FITTING_MATERIAL_OTHER', 'FIRST_PIPE_MATERIAL_OTHER','FIRST_PIPE_PLASTIC_OTHER',  'SECOND_PIPE_MATERIAL_OTHER', 'SECOND_PIPE_PLASTIC_OTHER', 'MFF_NUMBER_FROM_OPERATOR']
df = df.drop(columns=columns_to_drop)

# Display the first few rows to confirm the columns have been removed
display(df.head())
# Out:
#   DATAFILE_AS_OF          FORM_REV  OPERATOR_ID  REPORT_YEAR  \
# 0       4/3/2018  7100.1-2 10-2014         1209         2018
# 1       4/3/2018  7100.1-2 10-2014         1209         2018
# 2       4/3/2018  7100.1-2 10-2014         1209         2018
# 3       4/3/2018  7100.1-2 10-2014         1209         2018
# 4       4/3/2018  7100.1-2 10-2014         1209         2018
#
#        REPORT_NUMBER  SUPPLEMENTAL_NUMBER REPORT_TYPE REPORT_DATE FILING_DATE  \
# 0  20180227120985471                85414     INITIAL    3/6/2018    3/6/2018
# 1  20180219120985470                85413     INITIAL    3/6/2018    3/6/2018
# 2  20180216120985468                85411     INITIAL    3/6/2018    3/6/2018
# 3  20180215120985467                85410     INITIAL    3/6/2018    3/6/2018
# 4  20180215120985466                85409     INITIAL    3/6/2018    3/6/2018
#
#                    OPERATOR_NAME  ... SECOND_PIPE_NOMINAL_SIZE_TEXT  \
# 0  COLUMBIA GAS OF MASSACHUSETTS  ...                          3/4?
# 1  COLUMBIA GAS OF MASSACHUSETTS  ...                          1/2?
# 2  COLUMBIA GAS OF MASSACHUSETTS  ...                          3/4?
# 3  COLUMBIA GAS OF MASSACHUSETTS  ...                            2?
# 4  COLUMBIA GAS OF MASSACHUSETTS  ...                            1?
#
#   SECOND_PIPE_UNIT_TEXT SECOND_PIPE_MATERIAL_TEXT SECOND_PIPE_PLASTIC_TEXT  \
# 0                   IPS                     STEEL                      NaN
# 1                   CTS                   PLASTIC        POLYETHYLENE (PE)
# 2                   IPS                     STEEL                      NaN
# 3                   IPS                     STEEL                      NaN
# 4                   IPS                     STEEL                      NaN
#
#   LEAK_CAUSE_TEXT LEAK_CAUSE_OTHER NF_THERMAL_EXP_TEXT  \
# 0           OTHER   NOT DETERMINED                 NaN
# 1       CORROSION              NaN                 NaN
# 2           OTHER   NOT DETERMINED                 NaN
# 3           OTHER   NOT DETERMINED                 NaN
# 4  NATURAL FORCES              NaN                  NO
#
#   EX_DAMAGE_OCCURRED_TEXT MAT_WELDS_LEAK_CAUSE_TEXT   LEAK_OCCURRED_TEXT
# 0                     NaN                       NaN  LEAKED THROUGH SEAL
# 1                     NaN                       NaN  LEAKED THROUGH BODY
# 2                     NaN                       NaN  LEAKED THROUGH SEAL
# 3                     NaN                       NaN  LEAKED THROUGH SEAL
# 4                     NaN                       NaN  LEAKED THROUGH SEAL
#
# [5 rows x 41 columns]

# %%
# Remove columns from index 0 to 15
df = df.drop(df.columns[0:16], axis=1)

# Display the first few rows to confirm the columns have been removed
display(df.head())
# Out:
#   FAILURE_DATE MF_INVOLVED_TEXT MF_TYPE_TEXT LEAK_LOCATION_A_TEXT  \
# 0    2/27/2018     NUT FOLLOWER        VALVE          BELOWGROUND
# 1    2/19/2018     NUT FOLLOWER        RISER          BELOWGROUND
# 2    2/16/2018     NUT FOLLOWER     COUPLING          BELOWGROUND
# 3    2/15/2018     NUT FOLLOWER     COUPLING          BELOWGROUND
# 4    2/15/2018     NUT FOLLOWER        VALVE          BELOWGROUND
#
#   LEAK_LOCATION_B_TEXT LEAK_LOCATION_C_TEXT YEAR_INSTALLED YEAR_MANUFACTURED  \
# 0              OUTSIDE   SERVICE-TO-SERVICE           1982              1982
# 1              OUTSIDE   SERVICE-TO-SERVICE            NaN               NaN
# 2              OUTSIDE   SERVICE-TO-SERVICE           1975           UNKNOWN
# 3              OUTSIDE         MAIN-TO-MAIN           1965              1965
# 4              OUTSIDE   SERVICE-TO-SERVICE           1985           UNKNOWN
#
#                                          MANUFACTURE MODEL_NUMBER  ...  \
# 0  DRESSER (DRESSER MANUFACTURING, DRESSER PIPING...          UKN  ...
# 1                                            UNKNOWN          UKN  ...
# 2                                            UNKNOWN          UKN  ...
# 3  DRESSER (DRESSER MANUFACTURING, DRESSER PIPING...          UKN  ...
# 4                                            UNKNOWN          UKN  ...
#
#   SECOND_PIPE_NOMINAL_SIZE_TEXT SECOND_PIPE_UNIT_TEXT  \
# 0                          3/4?                   IPS
# 1                          1/2?                   CTS
# 2                          3/4?                   IPS
# 3                            2?                   IPS
# 4                            1?                   IPS
#
#   SECOND_PIPE_MATERIAL_TEXT SECOND_PIPE_PLASTIC_TEXT LEAK_CAUSE_TEXT  \
# 0                     STEEL                      NaN           OTHER
# 1                   PLASTIC        POLYETHYLENE (PE)       CORROSION
# 2                     STEEL                      NaN           OTHER
# 3                     STEEL                      NaN           OTHER
# 4                     STEEL                      NaN  NATURAL FORCES
#
#   LEAK_CAUSE_OTHER NF_THERMAL_EXP_TEXT EX_DAMAGE_OCCURRED_TEXT  \
# 0   NOT DETERMINED                 NaN                     NaN
# 1              NaN                 NaN                     NaN
# 2   NOT DETERMINED                 NaN                     NaN
# 3   NOT DETERMINED                 NaN                     NaN
# 4              NaN                  NO                     NaN
#
#   MAT_WELDS_LEAK_CAUSE_TEXT   LEAK_OCCURRED_TEXT
# 0                       NaN  LEAKED THROUGH SEAL
# 1                       NaN  LEAKED THROUGH BODY
# 2                       NaN  LEAKED THROUGH SEAL
# 3                       NaN  LEAKED THROUGH SEAL
# 4                       NaN  LEAKED THROUGH SEAL
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85611 entries, 0 to 85610
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   FAILURE_DATE                   85611 non-null  object
#  1   MF_INVOLVED_TEXT               85611 non-null  object
#  2   MF_TYPE_TEXT                   85611 non-null  object
#  3   LEAK_LOCATION_A_TEXT           85602 non-null  object
#  4   LEAK_LOCATION_B_TEXT           85611 non-null  object
#  5   LEAK_LOCATION_C_TEXT           85611 non-null  object
#  6   YEAR_INSTALLED                 62279 non-null  object
#  7   YEAR_MANUFACTURED              58424 non-null  object
#  8   MANUFACTURE                    85558 non-null  object
#  9   MODEL_NUMBER                   85017 non-null  object
#  10  FITTING_MATERIAL_TEXT          85611 non-null  object
#  11  FIRST_PIPE_NOMINAL_SIZE_TEXT   85611 non-null  object
#  12  FIRST_PIPE_UNIT_TEXT           85611 non-null  object
#  13  FIRST_PIPE_MATERIAL_TEXT       85611 non-null  object
#  14  FIRST_PIPE_PLASTIC_TEXT        26758 non-null  object
#  15  SECOND_PIPE_NOMINAL_SIZE_TEXT  85314 non-null  object
#  16  SECOND_PIPE_UNIT_TEXT          85316 non-null  object
#  17  SECOND_PIPE_MATERIAL_TEXT      85316 non-null  object
#  18  SECOND_PIPE_PLASTIC_TEXT       27029 non-null  object
#  19  LEAK_CAUSE_TEXT                85611 non-null  object
#  20  LEAK_CAUSE_OTHER               6344 non-null   object
#  21  NF_THERMAL_EXP_TEXT            12845 non-null  object
#  22  EX_DAMAGE_OCCURRED_TEXT        2108 non-null   object
#  23  MAT_WELDS_LEAK_CAUSE_TEXT      12551 non-null  object
#  24  LEAK_OCCURRED_TEXT             85611 non-null  object
# dtypes: object(25)
# memory usage: 16.3+ MB

# %%
for col in df.columns:
    non_null_value = df[col].dropna().iloc[0] if not df[col].dropna().empty else "No non-null values"
    print(f"{col}: {non_null_value}")
# Out:
# FAILURE_DATE: 2/27/2018
# MF_INVOLVED_TEXT: NUT FOLLOWER
# MF_TYPE_TEXT: VALVE
# LEAK_LOCATION_A_TEXT: BELOWGROUND
# LEAK_LOCATION_B_TEXT: OUTSIDE
# LEAK_LOCATION_C_TEXT: SERVICE-TO-SERVICE
# YEAR_INSTALLED: 1982
# YEAR_MANUFACTURED: 1982
# MANUFACTURE: DRESSER (DRESSER MANUFACTURING, DRESSER PIPING SPECIALTIES)
# MODEL_NUMBER: UKN
# FITTING_MATERIAL_TEXT: STEEL
# FIRST_PIPE_NOMINAL_SIZE_TEXT: 3/4?
# FIRST_PIPE_UNIT_TEXT: IPS
# FIRST_PIPE_MATERIAL_TEXT: STEEL
# FIRST_PIPE_PLASTIC_TEXT: POLYETHYLENE (PE)
# SECOND_PIPE_NOMINAL_SIZE_TEXT: 3/4?
# SECOND_PIPE_UNIT_TEXT: IPS
# SECOND_PIPE_MATERIAL_TEXT: STEEL
# SECOND_PIPE_PLASTIC_TEXT: POLYETHYLENE (PE)
# LEAK_CAUSE_TEXT: OTHER
# LEAK_CAUSE_OTHER: NOT DETERMINED
# NF_THERMAL_EXP_TEXT: NO
# EX_DAMAGE_OCCURRED_TEXT: AT TIME OF LEAK DISCOVERY
# MAT_WELDS_LEAK_CAUSE_TEXT: DESIGN DEFECT
# LEAK_OCCURRED_TEXT: LEAKED THROUGH SEAL

# %%
# Remove columns by name
columns_to_drop = ['YEAR_MANUFACTURED', 'LEAK_CAUSE_OTHER']
df = df.drop(columns=columns_to_drop)

# Display the first few rows to confirm the columns have been removed
display(df.head())
# Out:
#   FAILURE_DATE MF_INVOLVED_TEXT MF_TYPE_TEXT LEAK_LOCATION_A_TEXT  \
# 0    2/27/2018     NUT FOLLOWER        VALVE          BELOWGROUND
# 1    2/19/2018     NUT FOLLOWER        RISER          BELOWGROUND
# 2    2/16/2018     NUT FOLLOWER     COUPLING          BELOWGROUND
# 3    2/15/2018     NUT FOLLOWER     COUPLING          BELOWGROUND
# 4    2/15/2018     NUT FOLLOWER        VALVE          BELOWGROUND
#
#   LEAK_LOCATION_B_TEXT LEAK_LOCATION_C_TEXT YEAR_INSTALLED  \
# 0              OUTSIDE   SERVICE-TO-SERVICE           1982
# 1              OUTSIDE   SERVICE-TO-SERVICE            NaN
# 2              OUTSIDE   SERVICE-TO-SERVICE           1975
# 3              OUTSIDE         MAIN-TO-MAIN           1965
# 4              OUTSIDE   SERVICE-TO-SERVICE           1985
#
#                                          MANUFACTURE MODEL_NUMBER  \
# 0  DRESSER (DRESSER MANUFACTURING, DRESSER PIPING...          UKN
# 1                                            UNKNOWN          UKN
# 2                                            UNKNOWN          UKN
# 3  DRESSER (DRESSER MANUFACTURING, DRESSER PIPING...          UKN
# 4                                            UNKNOWN          UKN
#
#   FITTING_MATERIAL_TEXT  ... FIRST_PIPE_PLASTIC_TEXT  \
# 0                 STEEL  ...                     NaN
# 1                 STEEL  ...                     NaN
# 2                 STEEL  ...                     NaN
# 3                 STEEL  ...                     NaN
# 4                 STEEL  ...                     NaN
#
#   SECOND_PIPE_NOMINAL_SIZE_TEXT SECOND_PIPE_UNIT_TEXT  \
# 0                          3/4?                   IPS
# 1                          1/2?                   CTS
# 2                          3/4?                   IPS
# 3                            2?                   IPS
# 4                            1?                   IPS
#
#   SECOND_PIPE_MATERIAL_TEXT SECOND_PIPE_PLASTIC_TEXT LEAK_CAUSE_TEXT  \
# 0                     STEEL                      NaN           OTHER
# 1                   PLASTIC        POLYETHYLENE (PE)       CORROSION
# 2                     STEEL                      NaN           OTHER
# 3                     STEEL                      NaN           OTHER
# 4                     STEEL                      NaN  NATURAL FORCES
#
#   NF_THERMAL_EXP_TEXT EX_DAMAGE_OCCURRED_TEXT MAT_WELDS_LEAK_CAUSE_TEXT  \
# 0                 NaN                     NaN                       NaN
# 1                 NaN                     NaN                       NaN
# 2                 NaN                     NaN                       NaN
# 3                 NaN                     NaN                       NaN
# 4                  NO                     NaN                       NaN
#
#     LEAK_OCCURRED_TEXT
# 0  LEAKED THROUGH SEAL
# 1  LEAKED THROUGH BODY
# 2  LEAKED THROUGH SEAL
# 3  LEAKED THROUGH SEAL
# 4  LEAKED THROUGH SEAL
#
# [5 rows x 23 columns]

# %%
# Get unique values from the 'SECOND_PIPE_UNIT_TEXT' column
unique_values = df['SECOND_PIPE_UNIT_TEXT'].unique()

# Display the unique values
print("Unique values in SECOND_PIPE_UNIT_TEXT column:")
print(unique_values)
# Out:
# Unique values in SECOND_PIPE_UNIT_TEXT column:
# ['IPS' 'CTS' 'NPS' nan ' ']

# %%
for col in df.columns:
    non_null_value = df[col].dropna().iloc[0] if not df[col].dropna().empty else "No non-null values"
    print(f"{col}: {non_null_value}")
# Out:
# FAILURE_DATE: 2/27/2018
# MF_INVOLVED_TEXT: NUT FOLLOWER
# MF_TYPE_TEXT: VALVE
# LEAK_LOCATION_A_TEXT: BELOWGROUND
# LEAK_LOCATION_B_TEXT: OUTSIDE
# LEAK_LOCATION_C_TEXT: SERVICE-TO-SERVICE
# YEAR_INSTALLED: 1982
# MANUFACTURE: DRESSER (DRESSER MANUFACTURING, DRESSER PIPING SPECIALTIES)
# MODEL_NUMBER: UKN
# FITTING_MATERIAL_TEXT: STEEL
# FIRST_PIPE_NOMINAL_SIZE_TEXT: 3/4?
# FIRST_PIPE_UNIT_TEXT: IPS
# FIRST_PIPE_MATERIAL_TEXT: STEEL
# FIRST_PIPE_PLASTIC_TEXT: POLYETHYLENE (PE)
# SECOND_PIPE_NOMINAL_SIZE_TEXT: 3/4?
# SECOND_PIPE_UNIT_TEXT: IPS
# SECOND_PIPE_MATERIAL_TEXT: STEEL
# SECOND_PIPE_PLASTIC_TEXT: POLYETHYLENE (PE)
# LEAK_CAUSE_TEXT: OTHER
# NF_THERMAL_EXP_TEXT: NO
# EX_DAMAGE_OCCURRED_TEXT: AT TIME OF LEAK DISCOVERY
# MAT_WELDS_LEAK_CAUSE_TEXT: DESIGN DEFECT
# LEAK_OCCURRED_TEXT: LEAKED THROUGH SEAL

# %%
# Get the total number of rows
total_rows = len(df)

# Get the count of null values for each column
null_counts = df.isnull().sum()

# Calculate the count of non-null values for each column
non_null_counts = total_rows - null_counts

# Display the null and non-null counts
print("Null values per column:")
display(null_counts)

print("\nNon-null values per column:")
display(non_null_counts)
# Out:
# Null values per column:
# FAILURE_DATE                         0
# MF_INVOLVED_TEXT                     0
# MF_TYPE_TEXT                         0
# LEAK_LOCATION_A_TEXT                 9
# LEAK_LOCATION_B_TEXT                 0
# LEAK_LOCATION_C_TEXT                 0
# YEAR_INSTALLED                   23332
# MANUFACTURE                         53
# MODEL_NUMBER                       594
# FITTING_MATERIAL_TEXT                0
# FIRST_PIPE_NOMINAL_SIZE_TEXT         0
# FIRST_PIPE_UNIT_TEXT                 0
# FIRST_PIPE_MATERIAL_TEXT             0
# FIRST_PIPE_PLASTIC_TEXT          58853
# SECOND_PIPE_NOMINAL_SIZE_TEXT      297
# SECOND_PIPE_UNIT_TEXT              295
# SECOND_PIPE_MATERIAL_TEXT          295
# SECOND_PIPE_PLASTIC_TEXT         58582
# LEAK_CAUSE_TEXT                      0
# NF_THERMAL_EXP_TEXT              72766
# EX_DAMAGE_OCCURRED_TEXT          83503
# MAT_WELDS_LEAK_CAUSE_TEXT        73060
# LEAK_OCCURRED_TEXT                   0
# dtype: int64
# Non-null values per column:
# FAILURE_DATE                     85611
# MF_INVOLVED_TEXT                 85611
# MF_TYPE_TEXT                     85611
# LEAK_LOCATION_A_TEXT             85602
# LEAK_LOCATION_B_TEXT             85611
# LEAK_LOCATION_C_TEXT             85611
# YEAR_INSTALLED                   62279
# MANUFACTURE                      85558
# MODEL_NUMBER                     85017
# FITTING_MATERIAL_TEXT            85611
# FIRST_PIPE_NOMINAL_SIZE_TEXT     85611
# FIRST_PIPE_UNIT_TEXT             85611
# FIRST_PIPE_MATERIAL_TEXT         85611
# FIRST_PIPE_PLASTIC_TEXT          26758
# SECOND_PIPE_NOMINAL_SIZE_TEXT    85314
# SECOND_PIPE_UNIT_TEXT            85316
# SECOND_PIPE_MATERIAL_TEXT        85316
# SECOND_PIPE_PLASTIC_TEXT         27029
# LEAK_CAUSE_TEXT                  85611
# NF_THERMAL_EXP_TEXT              12845
# EX_DAMAGE_OCCURRED_TEXT           2108
# MAT_WELDS_LEAK_CAUSE_TEXT        12551
# LEAK_OCCURRED_TEXT               85611
# dtype: int64

# %%
# Remove columns with high null values
columns_to_drop = ['NF_THERMAL_EXP_TEXT', 'EX_DAMAGE_OCCURRED_TEXT', 'MAT_WELDS_LEAK_CAUSE_TEXT']
df = df.drop(columns=columns_to_drop)

# Display the first few rows to confirm the columns have been removed
display(df.head())
# Out:
#   FAILURE_DATE MF_INVOLVED_TEXT MF_TYPE_TEXT LEAK_LOCATION_A_TEXT  \
# 0    2/27/2018     NUT FOLLOWER        VALVE          BELOWGROUND
# 1    2/19/2018     NUT FOLLOWER        RISER          BELOWGROUND
# 2    2/16/2018     NUT FOLLOWER     COUPLING          BELOWGROUND
# 3    2/15/2018     NUT FOLLOWER     COUPLING          BELOWGROUND
# 4    2/15/2018     NUT FOLLOWER        VALVE          BELOWGROUND
#
#   LEAK_LOCATION_B_TEXT LEAK_LOCATION_C_TEXT YEAR_INSTALLED  \
# 0              OUTSIDE   SERVICE-TO-SERVICE           1982
# 1              OUTSIDE   SERVICE-TO-SERVICE            NaN
# 2              OUTSIDE   SERVICE-TO-SERVICE           1975
# 3              OUTSIDE         MAIN-TO-MAIN           1965
# 4              OUTSIDE   SERVICE-TO-SERVICE           1985
#
#                                          MANUFACTURE MODEL_NUMBER  \
# 0  DRESSER (DRESSER MANUFACTURING, DRESSER PIPING...          UKN
# 1                                            UNKNOWN          UKN
# 2                                            UNKNOWN          UKN
# 3  DRESSER (DRESSER MANUFACTURING, DRESSER PIPING...          UKN
# 4                                            UNKNOWN          UKN
#
#   FITTING_MATERIAL_TEXT FIRST_PIPE_NOMINAL_SIZE_TEXT FIRST_PIPE_UNIT_TEXT  \
# 0                 STEEL                         3/4?                  IPS
# 1                 STEEL                         3/4?                  IPS
# 2                 STEEL                         3/4?                  IPS
# 3                 STEEL                           2?                  IPS
# 4                 STEEL                           1?                  IPS
#
#   FIRST_PIPE_MATERIAL_TEXT FIRST_PIPE_PLASTIC_TEXT  \
# 0                    STEEL                     NaN
# 1                    STEEL                     NaN
# 2                    STEEL                     NaN
# 3                    STEEL                     NaN
# 4                    STEEL                     NaN
#
#   SECOND_PIPE_NOMINAL_SIZE_TEXT SECOND_PIPE_UNIT_TEXT  \
# 0                          3/4?                   IPS
# 1                          1/2?                   CTS
# 2                          3/4?                   IPS
# 3                            2?                   IPS
# 4                            1?                   IPS
#
#   SECOND_PIPE_MATERIAL_TEXT SECOND_PIPE_PLASTIC_TEXT LEAK_CAUSE_TEXT  \
# 0                     STEEL                      NaN           OTHER
# 1                   PLASTIC        POLYETHYLENE (PE)       CORROSION
# 2                     STEEL                      NaN           OTHER
# 3                     STEEL                      NaN           OTHER
# 4                     STEEL                      NaN  NATURAL FORCES
#
#     LEAK_OCCURRED_TEXT
# 0  LEAKED THROUGH SEAL
# 1  LEAKED THROUGH BODY
# 2  LEAKED THROUGH SEAL
# 3  LEAKED THROUGH SEAL
# 4  LEAKED THROUGH SEAL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85611 entries, 0 to 85610
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   FAILURE_DATE                   85611 non-null  object
#  1   MF_INVOLVED_TEXT               85611 non-null  object
#  2   MF_TYPE_TEXT                   85611 non-null  object
#  3   LEAK_LOCATION_A_TEXT           85602 non-null  object
#  4   LEAK_LOCATION_B_TEXT           85611 non-null  object
#  5   LEAK_LOCATION_C_TEXT           85611 non-null  object
#  6   YEAR_INSTALLED                 62279 non-null  object
#  7   MANUFACTURE                    85558 non-null  object
#  8   MODEL_NUMBER                   85017 non-null  object
#  9   FITTING_MATERIAL_TEXT          85611 non-null  object
#  10  FIRST_PIPE_NOMINAL_SIZE_TEXT   85611 non-null  object
#  11  FIRST_PIPE_UNIT_TEXT           85611 non-null  object
#  12  FIRST_PIPE_MATERIAL_TEXT       85611 non-null  object
#  13  FIRST_PIPE_PLASTIC_TEXT        26758 non-null  object
#  14  SECOND_PIPE_NOMINAL_SIZE_TEXT  85314 non-null  object
#  15  SECOND_PIPE_UNIT_TEXT          85316 non-null  object
#  16  SECOND_PIPE_MATERIAL_TEXT      85316 non-null  object
#  17  SECOND_PIPE_PLASTIC_TEXT       27029 non-null  object
#  18  LEAK_CAUSE_TEXT                85611 non-null  object
#  19  LEAK_OCCURRED_TEXT             85611 non-null  object
# dtypes: object(20)
# memory usage: 13.1+ MB

# %%
# Save the DataFrame to a new CSV file
df.to_csv('cleaned_data.csv', index=False)

print("DataFrame saved to cleaned_data.csv")
# Out:
# DataFrame saved to cleaned_data.csv

# %%
from google.colab import files

files.download('cleaned_data.csv')

# %%
import pandas as pd

# Convert 'FAILURE_DATE' to datetime objects
df['FAILURE_DATE'] = pd.to_datetime(df['FAILURE_DATE'])

# Extract the year and create the new 'FAILURE_YEAR' column
df['FAILURE_YEAR'] = df['FAILURE_DATE'].dt.year

# Remove the original 'FAILURE_DATE' column
df = df.drop(columns=['FAILURE_DATE'])

# Get a list of all columns
cols = df.columns.tolist()

# Remove 'FAILURE_YEAR' from the list
cols.remove('FAILURE_YEAR')

# Insert 'FAILURE_YEAR' at the beginning of the list
cols.insert(0, 'FAILURE_YEAR')

# Reindex the DataFrame with the new column order
df = df[cols]

# Display the first few rows to confirm the changes
display(df.head())
# Out:
#    FAILURE_YEAR MF_INVOLVED_TEXT MF_TYPE_TEXT LEAK_LOCATION_A_TEXT  \
# 0          2018     NUT FOLLOWER        VALVE          BELOWGROUND
# 1          2018     NUT FOLLOWER        RISER          BELOWGROUND
# 2          2018     NUT FOLLOWER     COUPLING          BELOWGROUND
# 3          2018     NUT FOLLOWER     COUPLING          BELOWGROUND
# 4          2018     NUT FOLLOWER        VALVE          BELOWGROUND
#
#   LEAK_LOCATION_B_TEXT LEAK_LOCATION_C_TEXT YEAR_INSTALLED  \
# 0              OUTSIDE   SERVICE-TO-SERVICE           1982
# 1              OUTSIDE   SERVICE-TO-SERVICE            NaN
# 2              OUTSIDE   SERVICE-TO-SERVICE           1975
# 3              OUTSIDE         MAIN-TO-MAIN           1965
# 4              OUTSIDE   SERVICE-TO-SERVICE           1985
#
#                                          MANUFACTURE MODEL_NUMBER  \
# 0  DRESSER (DRESSER MANUFACTURING, DRESSER PIPING...          UKN
# 1                                            UNKNOWN          UKN
# 2                                            UNKNOWN          UKN
# 3  DRESSER (DRESSER MANUFACTURING, DRESSER PIPING...          UKN
# 4                                            UNKNOWN          UKN
#
#   FITTING_MATERIAL_TEXT FIRST_PIPE_NOMINAL_SIZE_TEXT FIRST_PIPE_UNIT_TEXT  \
# 0                 STEEL                         3/4?                  IPS
# 1                 STEEL                         3/4?                  IPS
# 2                 STEEL                         3/4?                  IPS
# 3                 STEEL                           2?                  IPS
# 4                 STEEL                           1?                  IPS
#
#   FIRST_PIPE_MATERIAL_TEXT FIRST_PIPE_PLASTIC_TEXT  \
# 0                    STEEL                     NaN
# 1                    STEEL                     NaN
# 2                    STEEL                     NaN
# 3                    STEEL                     NaN
# 4                    STEEL                     NaN
#
#   SECOND_PIPE_NOMINAL_SIZE_TEXT SECOND_PIPE_UNIT_TEXT  \
# 0                          3/4?                   IPS
# 1                          1/2?                   CTS
# 2                          3/4?                   IPS
# 3                            2?                   IPS
# 4                            1?                   IPS
#
#   SECOND_PIPE_MATERIAL_TEXT SECOND_PIPE_PLASTIC_TEXT LEAK_CAUSE_TEXT  \
# 0                     STEEL                      NaN           OTHER
# 1                   PLASTIC        POLYETHYLENE (PE)       CORROSION
# 2                     STEEL                      NaN           OTHER
# 3                     STEEL                      NaN           OTHER
# 4                     STEEL                      NaN  NATURAL FORCES
#
#     LEAK_OCCURRED_TEXT
# 0  LEAKED THROUGH SEAL
# 1  LEAKED THROUGH BODY
# 2  LEAKED THROUGH SEAL
# 3  LEAKED THROUGH SEAL
# 4  LEAKED THROUGH SEAL

# %%
display(df.tail())
# Out:
#        FAILURE_YEAR MF_INVOLVED_TEXT         MF_TYPE_TEXT  \
# 85606          2011     NUT FOLLOWER                OTHER
# 85607          2011     NUT FOLLOWER             COUPLING
# 85608          2011     NUT FOLLOWER  SERVICE OR MAIN TEE
# 85609          2011     NUT FOLLOWER             COUPLING
# 85610          2011     NUT FOLLOWER             COUPLING
#
#       LEAK_LOCATION_A_TEXT LEAK_LOCATION_B_TEXT LEAK_LOCATION_C_TEXT  \
# 85606          BELOWGROUND              OUTSIDE   SERVICE-TO-SERVICE
# 85607          BELOWGROUND              OUTSIDE   SERVICE-TO-SERVICE
# 85608          BELOWGROUND              OUTSIDE      MAIN-TO-SERVICE
# 85609          BELOWGROUND              OUTSIDE         MAIN-TO-MAIN
# 85610          BELOWGROUND              OUTSIDE         MAIN-TO-MAIN
#
#       YEAR_INSTALLED MANUFACTURE MODEL_NUMBER FITTING_MATERIAL_TEXT  \
# 85606            NaN     UNKNOWN      UNKNOWN                 STEEL
# 85607           1958     UNKNOWN      UNKNOWN                 STEEL
# 85608           1958     UNKNOWN      UNKNOWN                 STEEL
# 85609           1963     UNKNOWN      UNKNOWN                 STEEL
# 85610           1966     UNKNOWN      UNKNOWN                 STEEL
#
#       FIRST_PIPE_NOMINAL_SIZE_TEXT FIRST_PIPE_UNIT_TEXT  \
# 85606                       1-1/4?                  IPS
# 85607                       1-1/2?                  IPS
# 85608                         3/4?                  IPS
# 85609                           2?                  IPS
# 85610                           2?                  CTS
#
#       FIRST_PIPE_MATERIAL_TEXT FIRST_PIPE_PLASTIC_TEXT  \
# 85606                    STEEL                     NaN
# 85607                    STEEL                     NaN
# 85608                    STEEL                     NaN
# 85609                    STEEL                     NaN
# 85610                    STEEL                     NaN
#
#       SECOND_PIPE_NOMINAL_SIZE_TEXT SECOND_PIPE_UNIT_TEXT  \
# 85606                        1-1/4?                   IPS
# 85607                        1-1/2?                   IPS
# 85608                        1-1/4?                   IPS
# 85609                            2?                   IPS
# 85610                            2?                   IPS
#
#       SECOND_PIPE_MATERIAL_TEXT SECOND_PIPE_PLASTIC_TEXT LEAK_CAUSE_TEXT  \
# 85606                     STEEL                      NaN  NATURAL FORCES
# 85607                     STEEL                      NaN  NATURAL FORCES
# 85608                     STEEL                      NaN  NATURAL FORCES
# 85609                     STEEL                      NaN       EQUIPMENT
# 85610                     STEEL                      NaN       EQUIPMENT
#
#         LEAK_OCCURRED_TEXT
# 85606  LEAKED THROUGH SEAL
# 85607  LEAKED THROUGH SEAL
# 85608  LEAKED THROUGH SEAL
# 85609  LEAKED THROUGH SEAL
# 85610  LEAKED THROUGH SEAL

# %%
# Get unique values from the 'LEAK_CAUSE_TEXT' column
unique_values = df['LEAK_CAUSE_TEXT'].unique()

# Display the unique values
print("Unique values in LEAK_CAUSE_TEXT column:")
print(unique_values)
# Out:
# Unique values in LEAK_CAUSE_TEXT column:
# ['OTHER' 'CORROSION' 'NATURAL FORCES' 'INCORRECT OPERATION' 'EQUIPMENT'
#  'MATERIAL OR WELDS/FUSIONS' 'EXCAVATION DAMAGE'
#  'OTHER OUTSIDE FORCE DAMAGE']

# %%
# Convert 'YEAR_INSTALLED' and 'FAILURE_YEAR' to numeric, coercing errors to NaN
df['YEAR_INSTALLED'] = pd.to_numeric(df['YEAR_INSTALLED'], errors='coerce')
df['FAILURE_YEAR'] = pd.to_numeric(df['FAILURE_YEAR'], errors='coerce')

# Create the 'SERVICE LIFE' by subtracting 'YEAR_INSTALLED' from 'FAILURE_YEAR'
df['SERVICE LIFE'] = df['FAILURE_YEAR'] - df['YEAR_INSTALLED']

# Display the first few rows with the new column
display(df.head())
# Out:
#    FAILURE_YEAR MF_INVOLVED_TEXT MF_TYPE_TEXT LEAK_LOCATION_A_TEXT  \
# 0          2018     NUT FOLLOWER        VALVE          BELOWGROUND
# 1          2018     NUT FOLLOWER        RISER          BELOWGROUND
# 2          2018     NUT FOLLOWER     COUPLING          BELOWGROUND
# 3          2018     NUT FOLLOWER     COUPLING          BELOWGROUND
# 4          2018     NUT FOLLOWER        VALVE          BELOWGROUND
#
#   LEAK_LOCATION_B_TEXT LEAK_LOCATION_C_TEXT  YEAR_INSTALLED  \
# 0              OUTSIDE   SERVICE-TO-SERVICE          1982.0
# 1              OUTSIDE   SERVICE-TO-SERVICE             NaN
# 2              OUTSIDE   SERVICE-TO-SERVICE          1975.0
# 3              OUTSIDE         MAIN-TO-MAIN          1965.0
# 4              OUTSIDE   SERVICE-TO-SERVICE          1985.0
#
#                                          MANUFACTURE MODEL_NUMBER  \
# 0  DRESSER (DRESSER MANUFACTURING, DRESSER PIPING...          UKN
# 1                                            UNKNOWN          UKN
# 2                                            UNKNOWN          UKN
# 3  DRESSER (DRESSER MANUFACTURING, DRESSER PIPING...          UKN
# 4                                            UNKNOWN          UKN
#
#   FITTING_MATERIAL_TEXT  ... FIRST_PIPE_UNIT_TEXT FIRST_PIPE_MATERIAL_TEXT  \
# 0                 STEEL  ...                  IPS                    STEEL
# 1                 STEEL  ...                  IPS                    STEEL
# 2                 STEEL  ...                  IPS                    STEEL
# 3                 STEEL  ...                  IPS                    STEEL
# 4                 STEEL  ...                  IPS                    STEEL
#
#   FIRST_PIPE_PLASTIC_TEXT SECOND_PIPE_NOMINAL_SIZE_TEXT SECOND_PIPE_UNIT_TEXT  \
# 0                     NaN                          3/4?                   IPS
# 1                     NaN                          1/2?                   CTS
# 2                     NaN                          3/4?                   IPS
# 3                     NaN                            2?                   IPS
# 4                     NaN                            1?                   IPS
#
#   SECOND_PIPE_MATERIAL_TEXT SECOND_PIPE_PLASTIC_TEXT LEAK_CAUSE_TEXT  \
# 0                     STEEL                      NaN           OTHER
# 1                   PLASTIC        POLYETHYLENE (PE)       CORROSION
# 2                     STEEL                      NaN           OTHER
# 3                     STEEL                      NaN           OTHER
# 4                     STEEL                      NaN  NATURAL FORCES
#
#     LEAK_OCCURRED_TEXT SERVICE LIFE
# 0  LEAKED THROUGH SEAL         36.0
# 1  LEAKED THROUGH BODY          NaN
# 2  LEAKED THROUGH SEAL         43.0
# 3  LEAKED THROUGH SEAL         53.0
# 4  LEAKED THROUGH SEAL         33.0
#
# [5 rows x 21 columns]
